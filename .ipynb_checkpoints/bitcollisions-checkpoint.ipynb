# %% [markdown]
# # Import

# %%
#the usual 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

#rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, Draw, DataStructs, rdFingerprintGenerator, PandasTools, Descriptors
PandasTools.RenderImagesInAllDataFrames(images=False) # when true, it displays the structures in the DF output

#others
#from sklearn.metrics import jaccard_score
from matplotlib.colors import LogNorm
from tqdm import tqdm
from itertools import combinations

# %% [markdown]
# # Hafner data set

# %% [markdown]
# ## load dataset

# %%
# url = "https://media.githubusercontent.com/media/FennerLabs/pepper/refs/heads/main/data/soil/cpd_data_soil_all_data.tsv"
# dataset = pd.read_csv(url, sep='\t')

# downloaded it locally:
dataset = pd.read_csv('data/cpd_data_soil_all_data.tsv', sep='\t')


df = dataset[['compound_name', 'SMILES']].copy()
df['Structure'] = df['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
df
# Out:
#              compound_name                                             SMILES  \
# 0      1,3-Dichloropropene                                           ClC=CCCl
# 1    3-Chloroallyl alcohol                                            OCC=CCl
# 2     3-Chloroacrylic acid                                     O=C([O-])C=CCl
# 3      1-naphthylacetamide                              NC(=O)Cc1cccc2ccccc12
# 4    1-naphthoic acid (M2)                               O=C(O)c1cccc2ccccc12
# ..                     ...                                                ...
# 862              X11963422                           CC1OC(=O)C(Cc2ccccc2)C1O
# 863                X696476                                COc1ccnc(C(=O)O)c1O
# 864                XDE-777  COc1ccnc(C(=O)NC2COC(=O)C(Cc3ccccc3)C(OC(=O)C(...
# 865                X642188  COc1ccnc(C(=O)NC2COC(=O)C(Cc3ccccc3)C(OC(=O)C(...
# 866                X696872  COc1ccnc(C(=O)NC2COC(=O)C(Cc3ccccc3)C(O)C(C)OC...
#
#                                              Structure
# 0    <rdkit.Chem.rdchem.Mol object at 0x00000229304...
# 1    <rdkit.Chem.rdchem.Mol object at 0x00000229304...
# 2    <rdkit.Chem.rdchem.Mol object at 0x00000229304...
# 3    <rdkit.Chem.rdchem.Mol object at 0x00000229304...
# 4    <rdkit.Chem.rdchem.Mol object at 0x00000229304...
# ..                                                 ...
# 862  <rdkit.Chem.rdchem.Mol object at 0x00000229305...
# 863  <rdkit.Chem.rdchem.Mol object at 0x00000229305...
# 864  <rdkit.Chem.rdchem.Mol object at 0x00000229305...
# 865  <rdkit.Chem.rdchem.Mol object at 0x00000229305...
# 866  <rdkit.Chem.rdchem.Mol object at 0x00000229305...
#
# [867 rows x 3 columns]

# %% [markdown]
# ## define generators

# %%
# generators 
sizes = [256, 1024, 2048, 4096, 8192, 16384, 32768]

fp_generators = {
    "TopologicalTorsion": {
        "sparse": rdFingerprintGenerator.GetTopologicalTorsionGenerator(),
        "folded": {size: rdFingerprintGenerator.GetTopologicalTorsionGenerator(fpSize=size) for size in sizes}
    },
    "ECFP4": {
        "sparse": rdFingerprintGenerator.GetMorganGenerator(radius=2),
        "folded": {size: rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=size) for size in sizes}
    },
    "ECFP6": {
        "sparse": rdFingerprintGenerator.GetMorganGenerator(radius=3),
        "folded": {size: rdFingerprintGenerator.GetMorganGenerator(radius=3, fpSize=size) for size in sizes}
    },
    "AtomPair": {
        "sparse": rdFingerprintGenerator.GetAtomPairGenerator(),
        "folded": {size: rdFingerprintGenerator.GetAtomPairGenerator(fpSize=size) for size in sizes}
    },
    "RDKit": {
        "sparse": rdFingerprintGenerator.GetRDKitFPGenerator(),
        "folded": {size: rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=size) for size in sizes}
    }
}

# %% [markdown]
# ## Self collison count

# %% [raw]
# # run only once; results are stored in json collison_count
#
# all_results = []
#
# # loop over each generator
# for fp_name, gens in fp_generators.items():
#     records = []
#
#     # calculate the number of on bits for sparse and folded for each molecule
#     for mol in tqdm(df["Structure"], desc=f"Processing {fp_name}"):
#         rec = {"fingerprint": fp_name}
#
#         # sparse bits
#         rec["sparse_bits"] = len(gens["sparse"].GetSparseFingerprint(mol).GetOnBits())
#
#         # folded bits
#         for size, gen in gens["folded"].items():
#             rec[f"folded_bits_{size}"] = gen.GetFingerprint(mol).GetNumOnBits()
#
#         records.append(rec)
#
#     fp_df = pd.DataFrame(records)
#
#     # percentage of molecules where folding changed bit count
#     percent_col = { size: (fp_df["sparse_bits"] != fp_df[f"folded_bits_{size}"]).sum() * 100 / len(fp_df) for size in sizes}
#
#     s = pd.Series(percent_col, name=fp_name)
#     all_results.append(s)
#
# summary_df = pd.DataFrame(all_results)
# summary_df = summary_df.T
#
# #store df
# summary_df.to_json('data/pest_collision_count.json')
#
# #display
# summary_df

# %%
with open('data/pest_collision_count.json') as f: 
    collision_count = pd.DataFrame(json.load(f))

collision_count.index = collision_count.index.astype(int)
collision_count
# Out:
#        TopologicalTorsion      ECFP4      ECFP6   AtomPair      RDKit
# 256             74.163783  88.465975  92.733564  96.539792  98.615917
# 1024            37.831603  55.247982  68.627451  85.467128  97.462514
# 2048            20.876586  46.020761  55.478662  78.431373  97.116494
# 4096            13.379469  13.610150  22.145329  67.358708  95.386390
# 8192             8.996540   6.805075  11.880046  56.632065  94.117647
# 16384            4.036909   2.883506   5.767013  54.555940  90.657439
# 32768            2.191465   1.384083   2.652826  33.217993  83.275663

# %%
sns.color_palette("hls")
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.8287999999999999, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.3712),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.3712, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.8287999999999999)]

# %%
# %% plot the results 

labels = ["RDKit FP", "Atom Pair FP", "ECFP6" , "ECFP4" , "Torsion FP"  ]
order = ["RDKit", "AtomPair", "ECFP6" , "ECFP4" , "TopologicalTorsion"] 
markers = [ '^', 'p', 'H' , 'o' , 'v', ]
n=len(df)
i=0
plt.figure(figsize=(7,5))
for fp in order:
    plt.plot(collision_count[fp], marker=markers[i], label=labels[i], color=sns.color_palette("hls")[i], markeredgecolor='white',
                    markeredgewidth=.3,)
    i=i+1

plt.xlabel("Bit length", size=12, labelpad=15)
plt.ylabel('Molecules with atleast one bit collision (%)',size=12)
plt.xticks(sizes, rotation=90, size=10)
plt.yticks(size=10)
plt.legend( bbox_to_anchor=(1, 0.79) )
plt.grid(True, linestyle="--", alpha=0.3)
plt.text( x=33600, y=96.5, s=f'n = {n} compounds', horizontalalignment = 'right')
plt.savefig('new_figures/pest_selfcol_count.svg', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### example molecules with collisions

# %%
from IPython.display import SVG

self_col = {"type": "self_collision", 
            "smiles": "N=C(NC(N)=O)NC(=O)NS(=O)(=O)c1ccccc1CCC(F)(F)F", 
            "bit_id": 502, 
            "environments": {"NC(N)=O": [[3, 1]], "cS(N)(=O)=O": [[10, 1]]}}

cros_col = {"type": "cross_collision", 
            "SMILES_1": "CCOc1cc(NC(=O)OC(C)C)c([N+](=O)[O-])cc1OCC", 
            "SMILES_2": "CC1COC(Cn2cncn2)(c2ccc(Oc3ccc(Cl)cc3)cc2Cl)O1", 
            "clashing_bit": 330, 
            "environments_1": {"CC(C)OC(N)=O": [[9, 2]]}, 
            "environments_2": {"CC(C)OC(C)(c)O": [[26, 2]]}}

# %%
m = Chem.MolFromSmiles('N=C(NC(N)=O)NC(=O)NS(=O)(=O)c1ccccc1CCC(F)(F)F')

d2d = Draw.rdMolDraw2D.MolDraw2DSVG(300,300)
d2d.DrawMolecule(m)

d2d.FinishDrawing()
svg = d2d.GetDrawingText()

with open("new_figures/self_col.svg", "w") as f:
    f.write(svg)

# display the SVG
SVG(svg)

# %%
m = Chem.MolFromSmiles('CCOc1cc(NC(=O)OC(C)C)c([N+](=O)[O-])cc1OCC')

d2d = Draw.rdMolDraw2D.MolDraw2DSVG(300,300)
d2d.DrawMolecule(m)

d2d.FinishDrawing()
svg = d2d.GetDrawingText()

with open("new_figures/cross_col1.svg", "w") as f:
    f.write(svg)

# display the SVG
SVG(svg)

# %%
m = Chem.MolFromSmiles('CC1COC(Cn2cncn2)(c2ccc(Oc3ccc(Cl)cc3)cc2Cl)O1')

d2d = Draw.rdMolDraw2D.MolDraw2DSVG(300,300)
d2d.DrawMolecule(m)

d2d.FinishDrawing()
svg = d2d.GetDrawingText()

with open("new_figures/cros_col2.svg", "w") as f:
    f.write(svg)

# display the SVG
SVG(svg)

# %% [markdown]
# ## Similarity searching effects

# %%
## ecfp4 

mols = df.Structure
n = len(mols)

# fingerprints
ecfp4 = [rdFingerprintGenerator.GetMorganGenerator(radius = 2, fpSize=1024).GetFingerprint(m) for m in mols]
sparse_ecfp4 = [rdFingerprintGenerator.GetMorganGenerator(radius=2).GetSparseFingerprint(m) for m in mols]

# initialize histogram
counts = np.zeros((100, 100))

# loop over molecules, compare against all later ones
for i in range(n):
    sims_fold = DataStructs.BulkTanimotoSimilarity(ecfp4[i], ecfp4[i+1:])
    sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_ecfp4[i], sparse_ecfp4[i+1:])
    
    # update histogram 
    hist, _, _ = np.histogram2d(
        sims_fold, sims_sparse,
        bins=100, range=[[0,1],[0,1]]
    )
    counts += hist

# mask zero-count bins
counts_masked = np.ma.masked_where(counts == 0, counts)

# plot
plt.figure(figsize=(8, 6))

plt.pcolormesh(
    np.linspace(0,1,101),
    np.linspace(0,1,101),
    counts_masked.T,
    cmap="viridis",
    norm=LogNorm(vmin=1, vmax=counts.max())) # log scale is needed

plt.colorbar(label="count")
plt.xlabel("Tanimoto ECFP4 (1024) folded")
plt.ylabel("Tanimoto ECFP4 sparse")
plt.text( x= 0.01, y=0.965,  s=f'n = {n} compounds')
# plt.title(f"Similarity scores for unfolded vs folded ECFP4 \nfor {n} compounds")
plt.savefig('new_figures/pesticide_ecfp_sim_plot.svg', bbox_inches='tight')
plt.show()

# %%
# now for RDkit 

mols = df.Structure
n = len(mols)

# fingerprints
rdkitfp = [rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=1024).GetFingerprint(m) for m in mols]
sparse_rdkitfp= [rdFingerprintGenerator.GetRDKitFPGenerator().GetSparseFingerprint(m) for m in mols]

# initialize histogram
counts = np.zeros((100, 100))

# loop over molecules, compare against all later ones
for i in range(n):
    sims_fold = DataStructs.BulkTanimotoSimilarity(rdkitfp[i], rdkitfp[i+1:])
    sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_rdkitfp[i], sparse_rdkitfp[i+1:])
    
    # update histogram 
    hist, _, _ = np.histogram2d(
        sims_fold, sims_sparse,
        bins=100, range=[[0,1],[0,1]]
    )
    counts += hist

# mask zero-count bins
counts_masked = np.ma.masked_where(counts == 0, counts)

# plot
plt.figure(figsize=(8, 6))

plt.pcolormesh(
    np.linspace(0,1,101),
    np.linspace(0,1,101),
    counts_masked.T,
    cmap="viridis",
    norm=LogNorm(vmin=1, vmax=counts.max())) # log scale is needed

plt.colorbar(label="count")
plt.xlabel("Tanimoto RDKit (1024) folded")
plt.ylabel("Tanimoto RDkit sparse")
plt.text( x= 0.01, y=0.965,  s=f'n = {n} compounds')
# plt.title(f"Similarity scores for unfolded vs folded ECFP4 \nfor {n} compounds")
plt.savefig('new_figures/pesticide_rdkit_sim_plot.svg', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Large general dataset

# %% [markdown]
# ## Load dataset, curate and move to pickle

# %% [raw]
# # load data from the zero pm github
# url = "https://raw.githubusercontent.com/ZeroPM-H2020/global-chemical-inventory-database/refs/heads/main/csv_files/substances.csv"
# df = pd.read_csv(url)
#
# # inchi to structure
# df[  "Structure"  ] = df[  "inchi"  ].apply(lambda x: Chem.inchi.MolFromInchi(x))
#
# # drop everything that doesnt work
# to_drop = df.loc[df[  "Structure"  ].isnull() == True].index
# df = df.drop(to_drop)
# df.shape
#
# # safe the new df
# zeropm_substances = "zeropm_substances.csv"
# df.to_csv(zeropm_substances, index=False)

# %% [raw]
# import operator as op
#
# # import dataframe of the compounds without errors
# df = pd.read_csv("zeropm_substances.csv")
#
# #remove salts
# df[  "Salt"  ] = df[  inchi  ].apply(lambda x: op.contains(x, "." ))
# df = df.loc[df[  "Salt"  ] == False]
#
# # re-run structure as this doesnt save in csv
# df[  "Structure"  ] = df[  "inchi"  ].apply(lambda x: Chem.inchi.MolFromInchi(x, sanitize=True, removeHs=True))
#
# # remove the single atoms and diatoms
# df[  "NumAtoms"  ] = df[  "Structure"  ].apply(lambda x: x.GetNumAtoms())
# df = df.loc[df[  "NumAtoms"  ] > 2]
#
# df = df.set_index(  "inchi_id"  )
# df.shape

# %% [raw]
# # safe df in pickle so the molfrominchi does not have to be rerun
# df.to_pickle("./substances.pkl")

# %% [markdown]
# ## Load data

# %%
df_gen = pd.read_pickle("data/substances.pkl") 
df_gen
# Out:
#                                                       inchi  \
# inchi_id
# 1          InChI=1S/C6H4ClNO2/c7-5-1-3-6(4-2-5)8(9)10/h1-4H
# 2         InChI=1S/C6H6N2O2/c7-5-1-3-6(4-2-5)8(9)10/h1-4...
# 3          InChI=1S/C6H5NO3/c8-6-3-1-5(2-4-6)7(9)10/h1-4,8H
# 4         InChI=1S/C6H5ClO2S/c7-5-1-3-6(4-2-5)10(8)9/h1-...
# 7         InChI=1S/C9H10O2/c1-7(10)8-3-5-9(11-2)6-4-8/h3...
# ...                                                     ...
# 359105                  InChI=1S/O6Si2/c1-7(2)6-8(3,4)5/q-4
# 359107                InChI=1S/O7Si2/c1-8(2,3)7-9(4,5)6/q-6
# 359108             InChI=1S/O7Si3/c1-8(2)6-10(5)7-9(3)4/q-2
# 359109     InChI=1S/O8Si3/c1-9(2)5-11(6-9)7-10(3,4)8-11/q-4
# 359110          InChI=1S/O8Si3/c1-9(2)7-11(5,6)8-10(3)4/q-4
#
#                              inchikey  \
# inchi_id
# 1         CZGCEKJOLUNIFY-UHFFFAOYSA-N
# 2         TYMLOMAKGOJONV-UHFFFAOYSA-N
# 3         BTJIUGUIPKRLHP-UHFFFAOYSA-N
# 4         AOQYAMDZQAEDLO-UHFFFAOYSA-N
# 7         NTPLXRHDUXRPNE-UHFFFAOYSA-N
# ...                               ...
# 359105    NYRJGAMJBNFXOM-UHFFFAOYSA-N
# 359107    KUDCBYUNCUYIDU-UHFFFAOYSA-N
# 359108    MXSSWTMUAUJAKG-UHFFFAOYSA-N
# 359109    BGYSAZMVZNGKQJ-UHFFFAOYSA-N
# 359110    CZONNRSTWJECNT-UHFFFAOYSA-N
#
#                                                   Structure   Salt  NumAtoms
# inchi_id
# 1         <rdkit.Chem.rdchem.Mol object at 0x000001B3669...  False        10
# 2         <rdkit.Chem.rdchem.Mol object at 0x000001B3669...  False        10
# 3         <rdkit.Chem.rdchem.Mol object at 0x000001B3669...  False        10
# 4         <rdkit.Chem.rdchem.Mol object at 0x000001B3669...  False        10
# 7         <rdkit.Chem.rdchem.Mol object at 0x000001B3669...  False        11
# ...                                                     ...    ...       ...
# 359105    <rdkit.Chem.rdchem.Mol object at 0x000001B3B06...  False         8
# 359107    <rdkit.Chem.rdchem.Mol object at 0x000001B3B06...  False         9
# 359108    <rdkit.Chem.rdchem.Mol object at 0x000001B3B06...  False        10
# 359109    <rdkit.Chem.rdchem.Mol object at 0x000001B3B06...  False        11
# 359110    <rdkit.Chem.rdchem.Mol object at 0x000001B3B05...  False        11
#
# [258584 rows x 5 columns]

# %% [markdown]
# ## Self collision count

# %% [raw]
# # run only once; results are stored in json collison_count
#
# all_results = []
#
# # loop over each generator
# for fp_name, gens in fp_generators.items():
#     records = []
#
#     # calculate the number of on bits for sparse and folded for each molecule
#     for mol in tqdm(df["Structure"], desc=f"Processing {fp_name}"):
#         rec = {"fingerprint": fp_name}
#
#         # sparse bits
#         rec["sparse_bits"] = len(gens["sparse"].GetSparseFingerprint(mol).GetOnBits())
#
#         # folded bits
#         for size, gen in gens["folded"].items():
#             rec[f"folded_bits_{size}"] = gen.GetFingerprint(mol).GetNumOnBits()
#
#         records.append(rec)
#
#     fp_df = pd.DataFrame(records)
#
#     # percentage of molecules where folding changed bit count
#     percent_col = { size: (fp_df["sparse_bits"] != fp_df[f"folded_bits_{size}"]).sum() * 100 / len(fp_df) for size in sizes}
#
#     s = pd.Series(percent_col, name=fp_name)
#     all_results.append(s)
#
# summary_df = pd.DataFrame(all_results)
# summary_df = summary_df.T
#
# #store df
# summary_df.to_json('data/general_collision_count.json')
#
# #display
# summary_df

# %%
with open('data/general_collision_count.json') as f: 
    gen_collision_count = pd.DataFrame(json.load(f))

gen_collision_count.index = gen_collision_count.index.astype(int)
gen_collision_count
# Out:
#        TopologicalTorsion      ECFP4      ECFP6   AtomPair      RDKit
# 256             65.434830  80.328636  88.014726  97.164558  98.634486
# 1024            28.968536  46.978545  58.691180  77.151719  95.897658
# 2048            16.975528  37.989589  46.502877  64.541116  92.885097
# 4096            11.099295  10.023049  18.532082  51.727485  88.550722
# 8192             7.775810   6.102852  11.187854  35.873449  84.515283
# 16384            5.245878   2.847044   5.947390  31.435433  79.724190
# 32768            4.251616   1.080500   2.437893  19.133048  70.465303

# %%
labels = ["RDKit FP", "Atom Pair FP", "ECFP6" , "ECFP4" , "Torsion FP"  ]
order = ["RDKit", "AtomPair", "ECFP6" , "ECFP4" , "TopologicalTorsion"] 
markers = [ '^', 'p', 'H' , 'o' , 'v', ]
n=len(df_gen)

i=0
plt.figure(figsize=(7,5))
for fp in order:
    plt.plot(gen_collision_count[fp], marker=markers[i], label=labels[i], color=sns.color_palette("hls")[i], markeredgecolor='white',
                    markeredgewidth=.3,)
    i=i+1

plt.xlabel("Bit length", size=12, labelpad=15)
plt.ylabel('Molecules with atleast one bit collision (%)',size=12)
plt.xticks(sizes, rotation=90, size=10)
plt.yticks(size=10)
plt.legend( )
plt.grid(True, linestyle="--", alpha=0.3)
plt.text( x=33600, y=96.5, s=f'n = {n} compounds', horizontalalignment = 'right')
plt.savefig('new_figures/general_selfcol_count.svg', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### per size class

# %% [raw]
# plt.boxplot(df_gen['HeavyAtoms'])
# plt.show()

# %%
def size(x):
    if x<20: 
        return 'x-small'
    if x<75:
        return 'small'
    if x<200:
        return 'medium'
    else:
        return 'large'

df_gen['Size'] = df_gen['NumAtoms'].apply(lambda x: size(x))
grouped_wt = df_gen.groupby('Size')
grouped_wt.size()
# Out:
# Size
# large         208
# medium       2386
# small       97432
# x-small    158558
# dtype: int64

# %% [raw]
# # run ECFP4 for different sized molecules and save as json
#
# sizes = [256, 1024, 2048, 4096, 8192, 16384, 32768]
# fp_gen_sparse = rdFingerprintGenerator.GetMorganGenerator(radius=2)
# fp_gens_folded = {size: rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=size) for size in sizes}
#
#
# summary_rows = []
#
# for size_class, group in grouped_wt:
#
#     records = []
#
#     # loop over molecules with tqdm progress bar
#     for mol in tqdm(group['Structure'], desc=f"Processing molecules for class {size_class}"):
#         rec = {}
#
#         # sparse bits count
#         rec["sparse_bits"] = len(fp_gen_sparse.GetSparseFingerprint(mol).GetOnBits())
#
#         # folded bits counts
#         for size, gen in fp_gens_folded.items():
#             rec[f"folded_bits_{size}"] = gen.GetFingerprint(mol).GetNumOnBits()
#         records.append(rec)
#
#     bit_col_df = pd.DataFrame(records)
#
#     row = {"Size class": size_class}
#     for size in sizes:
#         row[size] = ((bit_col_df["sparse_bits"] != bit_col_df[f"folded_bits_{size}"]).mean()* 100)
#
#     summary_rows.append(row)
#
# size_df = pd.DataFrame(summary_rows)
#
# size_df = size_df.set_index('Size class')
# size_df = size_df.T
#
# size_df.to_json('data/general_count_weight_ECFP4.json')
#
# size_df

# %%
with open('data/general_count_weight_ECFP4.json') as f: 
    size_df = pd.DataFrame(json.load(f))

size_df.index = size_df.index.astype(int)
size_df
# Out:
#            large     medium      small    x-small
# 256    99.519231  97.359598  94.293456  71.465962
# 1024   97.115385  84.534786  64.346416  35.675273
# 2048   95.192308  79.882649  53.850891  27.537557
# 4096   56.730769  41.072925  18.011536   4.585704
# 8192   55.288462  28.792959  11.146235   2.597788
# 16384  27.884615  16.512992   5.125626   1.208391
# 32768  27.403846   7.544007   2.016791   0.373365

# %%
labels = ['>= 200', '< 200' , '< 75' , '< 20' ]

i=0
plt.figure()
for col in size_df.columns:
    plt.plot(size_df[col], label=labels[i], marker = '.', markersize = 10,  color=sns.color_palette("rocket")[i+2], markeredgecolor='white',
                    markeredgewidth=.3,)
    i=i+1

plt.xlabel("ECFP4 Bit length", size=12, labelpad=15)
plt.ylabel('Molecules with atleast one bit collision (%)',size=12)

plt.xticks(sizes, rotation=90, size=10)
plt.yticks(size=10)
plt.ylim(0,100)
plt.legend( title='Atom Count' )
plt.grid(True, linestyle="--", alpha=0.3)
plt.savefig('new_figures/general_selfcol_pw.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Similarity searching effect

# %%
# define
df_sample = df_gen.sample(n=5000, random_state=42)
mols = df_sample.Structure
n = len(mols)

sizes = [256, 1024, 2048, 4096, 8192]

for fp_name, gens in fp_generators.items():

    # sparse fingerprints
    sparse_fp = [gens["sparse"].GetSparseFingerprint(m) for m in mols]

    # folded fingerprints
    fingerprints = {size: [gens["folded"][size].GetFingerprint(m) for m in mols] for size in sizes}
    
    # subplot grid
    fig, axes = plt.subplots(1, len(sizes), figsize=(6*len(sizes), 4), sharex=True, sharey=True)
    
    for ax, size in zip(axes, sizes):
        fp = fingerprints[size]
        counts = np.zeros((100, 100))
    
        # make the 2d historgram
        for i in tqdm(range(n), desc=f"Processing fpSize={size}", unit="mol"):
            sims_fold = DataStructs.BulkTanimotoSimilarity(fp[i], fp[i+1:])
            sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_fp[i], sparse_fp[i+1:])
            
            hist, _, _ = np.histogram2d(
                sims_fold, sims_sparse,
                bins=100, range=[[0,1],[0,1]]
            )
            counts += hist
    
        # mask zero-count bin
        counts_masked = np.ma.masked_where(counts == 0, counts)
    
        # subplot
        mesh = ax.pcolormesh(
            np.linspace(0,1,101),
            np.linspace(0,1,101),
            counts_masked.T,
            cmap="viridis",
            norm=LogNorm(vmin=1, vmax=counts.max())
        )
        ax.set_xlabel(f"Tanimoto folded")
        ax.set_ylabel(f"Tanimoto sparse")
        ax.set_title(f"{fp_name}; {size} bits")
    
    #one shared colorbar
    fig.colorbar(mesh, ax=axes, label="count", pad=0.02)
    #  fig.suptitle(f"Similarity scores for unfolded vs folded {fp_name} for {n} compounds", fontsize=20, y=1.1, x=0.2)
    plt.savefig(f"new_figures/gen_{fp_name}_similarity.svg", bbox_inches="tight")
    plt.show()
# Out:
# Processing fpSize=256: 100%|█████████████████████████████████████████████████████| 5000/5000 [00:23<00:00, 212.14mol/s]
# Processing fpSize=1024: 100%|████████████████████████████████████████████████████| 5000/5000 [00:22<00:00, 220.70mol/s]
# Processing fpSize=2048: 100%|████████████████████████████████████████████████████| 5000/5000 [00:22<00:00, 217.43mol/s]
# Processing fpSize=4096: 100%|████████████████████████████████████████████████████| 5000/5000 [00:22<00:00, 220.98mol/s]
# Processing fpSize=8192: 100%|████████████████████████████████████████████████████| 5000/5000 [00:25<00:00, 199.99mol/s]
# Processing fpSize=256: 100%|█████████████████████████████████████████████████████| 5000/5000 [00:26<00:00, 192.06mol/s]
# Processing fpSize=1024: 100%|████████████████████████████████████████████████████| 5000/5000 [00:27<00:00, 183.35mol/s]
# Processing fpSize=2048: 100%|████████████████████████████████████████████████████| 5000/5000 [00:27<00:00, 182.50mol/s]
# Processing fpSize=4096: 100%|████████████████████████████████████████████████████| 5000/5000 [00:27<00:00, 179.56mol/s]
# Processing fpSize=8192: 100%|████████████████████████████████████████████████████| 5000/5000 [00:28<00:00, 173.50mol/s]
# Processing fpSize=256: 100%|█████████████████████████████████████████████████████| 5000/5000 [00:32<00:00, 152.60mol/s]
# Processing fpSize=1024: 100%|████████████████████████████████████████████████████| 5000/5000 [00:31<00:00, 157.97mol/s]
# Processing fpSize=2048: 100%|████████████████████████████████████████████████████| 5000/5000 [00:37<00:00, 132.23mol/s]
# Processing fpSize=4096: 100%|████████████████████████████████████████████████████| 5000/5000 [00:35<00:00, 140.72mol/s]
# Processing fpSize=8192: 100%|████████████████████████████████████████████████████| 5000/5000 [00:35<00:00, 139.42mol/s]
# Processing fpSize=256: 100%|██████████████████████████████████████████████████████| 5000/5000 [01:56<00:00, 42.78mol/s]
# Processing fpSize=1024: 100%|█████████████████████████████████████████████████████| 5000/5000 [01:55<00:00, 43.47mol/s]
# Processing fpSize=2048: 100%|█████████████████████████████████████████████████████| 5000/5000 [01:56<00:00, 43.02mol/s]
# Processing fpSize=4096: 100%|█████████████████████████████████████████████████████| 5000/5000 [01:56<00:00, 42.98mol/s]
# Processing fpSize=8192: 100%|█████████████████████████████████████████████████████| 5000/5000 [01:57<00:00, 42.39mol/s]
# Processing fpSize=256: 100%|██████████████████████████████████████████████████████| 5000/5000 [05:36<00:00, 14.87mol/s]
# Processing fpSize=1024: 100%|█████████████████████████████████████████████████████| 5000/5000 [05:23<00:00, 15.43mol/s]
# Processing fpSize=2048: 100%|█████████████████████████████████████████████████████| 5000/5000 [05:26<00:00, 15.33mol/s]
# Processing fpSize=4096: 100%|█████████████████████████████████████████████████████| 5000/5000 [05:15<00:00, 15.83mol/s]
# Processing fpSize=8192: 100%|█████████████████████████████████████████████████████| 5000/5000 [05:00<00:00, 16.66mol/s]

# %% [markdown]
# # old Bit collisions

# %% [raw]
#
# rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=nBits)
# rdFingerprintGenerator.GetAtomPairGenerator(fpSize=nBits)
# rdFingerprintGenerator.GetTopologicalTorsionGenerator(fpSize=nBits)
#
# AllChem.GetMorganGenerator(radius=2, fpSize=nBits)

# %%
# generators 
fp_gen_sparse = rdFingerprintGenerator.GetTopologicalTorsionGenerator()
sizes = [1024, 2048, 4096, 8192, 16384, 32768]
fp_gens_folded = {size: rdFingerprintGenerator.GetTopologicalTorsionGenerator(fpSize=size) for size in sizes}

records = []

# loop over molecules with tqdm progress bar
for mol in tqdm(df['Structure'], desc="Processing molecules"):
    rec = {}
    
    # sparse bits count
    rec["sparse_bits"] = len(fp_gen_sparse.GetSparseFingerprint(mol).GetOnBits())
    
    # folded bits counts
    for size, gen in fp_gens_folded.items():
        rec[f"folded_bits_{size}"] = gen.GetFingerprint(mol).GetNumOnBits()
    records.append(rec)

bit_col_df = pd.DataFrame(records)

# percentages calculation
percent_col = {
    size: f"{(bit_col_df['sparse_bits'] != bit_col_df[f'folded_bits_{size}']).sum() * 100 / len(df):0.1f}" for size in sizes}
percent_col
# Out:
# Processing molecules: 100%|██████████████████████████████████████████████████| 258584/258584 [03:58<00:00, 1084.39it/s]
# {1024: '29.0',
#  2048: '17.0',
#  4096: '11.1',
#  8192: '7.8',
#  16384: '5.2',
#  32768: '4.3'}

# %%
ECFP_4 = {1024: 47.0,
 2048: 38.0,
 4096: 10.0,
 8192: 6.1,
 16384: 2.8,
 32768: 1.1}

ECFP_6 = {1024: 58.7,
 2048: 46.5,
 4096: 18.5,
 8192: 11.2,
 16384: 5.9,
 32768: 2.4}

rdkit_fp = {1024:   95.9  ,
 2048:   92.9  ,
 4096:   88.6  ,
 8192:   84.5  ,
 16384:   79.7  ,
 32768:   70.5  }

atom_pair = {1024:   77.2  ,
 2048:   64.5  ,
 4096:   51.7  ,
 8192:   35.9  ,
 16384:   31.4  ,
 32768:   19.1  }

torsion = {1024:   29.0  ,
 2048:   17.0  ,
 4096:   11.1  ,
 8192:   7.8  ,
 16384:   5.2  ,
 32768:   4.3  }


labels = ["RDKit FP", "Atom Pair FP", "ECFP6" , "ECFP4" , "Torsion FP"  ]
fingerprints = [rdkit_fp , atom_pair, ECFP_6 , ECFP_4 , torsion ]
cmap = plt.cm.viridis
colors = cmap(np.linspace(0, 1, len(labels)+1))

i=0
plt.figure()
for fp in fingerprints:
    plt.plot(fp.keys(), fp.values(), marker='.', label=labels[i], color=colors[i])
    i=i+1

plt.xlabel("Bit length", size=12, labelpad=15)
plt.ylabel('Molecules with atleast one bit collision (%)',size=12)
plt.xticks([1024, 2048, 4096, 8192, 16384, 32768], rotation=90, size=12)
plt.yticks(size=12)
plt.legend()

#plt.savefig('bit_col_plot.png', bbox_inches='tight')
plt.show()

# %%
df['Weight'] = df['Structure'].apply(lambda x: Descriptors.MolWt(x))

def group_weight(x):
    #x is molweight
    if x<400:
        return 'small'
    if x<1000:
        return 'middle'
    else:
        return 'large'

df['Size class'] = df['Weight'].apply(lambda x: group_weight(x))
grouped_wt = df.groupby('Size class')
grouped_wt.size()
# Out:
# Size class
# large       3400
# middle     46958
# small     208226
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x=df['Size class'], y=df["Weight"])
plt.ylabel("Mol Weight")
plt.yscale('log')
plt.show()

# %%
# generators 
fp_gen_sparse = AllChem.GetMorganGenerator(radius=2)
sizes = [1024, 2048, 4096, 8192, 16384, 32768]
fp_gens_folded = {size: AllChem.GetMorganGenerator(radius=2, fpSize=size) for size in sizes}

summary_rows = []

for size_class, group in grouped_wt:

    records = []
    
    # loop over molecules with tqdm progress bar
    for mol in tqdm(group['Structure'], desc=f"Processing molecules for class {size_class}"):
        rec = {}
        
        # sparse bits count
        rec["sparse_bits"] = len(fp_gen_sparse.GetSparseFingerprint(mol).GetOnBits())
        
        # folded bits counts
        for size, gen in fp_gens_folded.items():
            rec[f"folded_bits_{size}"] = gen.GetFingerprint(mol).GetNumOnBits()
        records.append(rec)
    
    bit_col_df = pd.DataFrame(records)

    row = {"Size class": size_class}
    for size in sizes:
        row[f"% mismatch {size}"] = ((bit_col_df["sparse_bits"] != bit_col_df[f"folded_bits_{size}"]).mean()* 100)

    summary_rows.append(row)

summary_df = pd.DataFrame(summary_rows)
summary_df
# Out:
# Processing molecules for class large: 100%|███████████████████████████████████████| 3400/3400 [00:05<00:00, 578.59it/s]
# Processing molecules for class middle: 100%|███████████████████████████████████| 46958/46958 [00:24<00:00, 1937.68it/s]
# Processing molecules for class small: 100%|██████████████████████████████████| 208226/208226 [00:46<00:00, 4433.22it/s]
#   Size class  % mismatch 1024  % mismatch 2048  % mismatch 4096  \
# 0      large        84.000000        79.558824        41.441176
# 1     middle        71.148686        61.712594        24.074705
# 2      small        40.923324        31.960946         6.341187
#
#    % mismatch 8192  % mismatch 16384  % mismatch 32768
# 0        30.294118         17.088235          9.117647
# 1        15.000639          6.859321          2.789727
# 2         3.701267          1.709681          0.563810

# %% [raw]
# ## ECFP4 ##
#
# Total set
# {1024: 47.0,
#  2048: 38.0,
#  4096: 10.0,
#  8192: 6.1,
#  16384: 2.8,
#  32768: 1.1}
#
# Size class	% mismatch 1024	% mismatch 2048	% mismatch 4096	% mismatch 8192	% mismatch 16384	% mismatch 32768
# large	84.000000	79.558824	41.441176	30.294118	17.088235	9.117647
# middle	71.148686	61.712594	24.074705	15.000639	6.859321	2.789727
# small	40.923324	31.960946	6.341187	3.701267	1.709681	0.563810

# %%
size_effect_ecfp4 = {'large': [84.000000,	79.558824,	41.441176, 30.294118,	17.088235,	9.117647],
              'middle': [71.148686,	61.712594,	24.074705, 15.000639,	6.859321,	2.789727],
                'total': [47.0, 38.0, 10.0, 6.1, 2.8, 1.1],
              'small': [40.923324,	31.960946,	6.341187, 3.701267,	1.709681,	0.56381]}

size_effect_ecfp4 = pd.DataFrame.from_dict(size_effect_ecfp4, orient="index", 
                                           columns=[1024, 2048, 4096, 8192, 16384, 32768]).round(1)

size_effect_ecfp4 = size_effect_ecfp4.T
size_effect_ecfp4
# Out:
#        large  middle  total  small
# 1024    84.0    71.1   47.0   40.9
# 2048    79.6    61.7   38.0   32.0
# 4096    41.4    24.1   10.0    6.3
# 8192    30.3    15.0    6.1    3.7
# 16384   17.1     6.9    2.8    1.7
# 32768    9.1     2.8    1.1    0.6

# %%
colours = ['#BCDF27' ,'#7AD151' ,"#07281f" ,'#22a884']

plt.figure()

for col, color in zip(size_effect_ecfp4.columns, colours):
    plt.plot(size_effect_ecfp4[col],
             label=col,
             marker='.',
             color=color)

plt.xlabel("ECFP4 Bit length", size=12, labelpad=15)
plt.ylabel('Molecules with atleast one bit collision (%)',size=12)
plt.xticks([1024, 2048, 4096, 8192, 16384, 32768], rotation=90, size=12)
plt.yticks(size=12)
plt.ylim(0,100)


plt.legend()

#plt.savefig('bit_col_size_effect.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# # Example bit collision

# %%
def draw_top_morgan_bits(mols, bit_indices, radius=2, nBits=2048, max_mols=3, molsPerRow=3):
    """
    Draws substructures for ecfp bits across a list of RDKit molecules.
    
    Input:
    mols: list rdkit structures (from molforsmiles)
    bit_indices: list of integers of the bit to visualize 
    radius: Morgan fingerprint radius (default=2)
    nBits: fingerprint size (default=2048)
    max_mols: how many molecules to show per bit
    molsPerRow: number of molecules per row in the output grid
    """
    
    # generate morgan fp with a specific radius and bit length
    fpg = rdFingerprintGenerator.GetMorganGenerator(radius=radius, fpSize=nBits)

    for i, bit_idx in enumerate(bit_indices):
        tuples = []
        shown = 0

        # itteratively per molecule in the list of mols provided, untill max_mols is reached
        for mol in mols:
            if shown >= max_mols:
                break
            
            # store information about the bit, needed for visalisation     
            ao = rdFingerprintGenerator.AdditionalOutput()
            ao.AllocateBitInfoMap()
            fp = fpg.GetFingerprint(mol, additionalOutput=ao)
            bitInfo = ao.GetBitInfoMap()
            
            if bit_idx in bitInfo:
                tuples.append((mol, bit_idx, bitInfo))
                shown += 1
        
        if tuples:
            # image of the bit with its ID and the position on bit_indices
            print(f"Bit {bit_idx} (Top {i+1})")
            img = Draw.DrawMorganBits(tuples, molsPerRow=molsPerRow)
            display(img)
        else:
            print(f"Bit {bit_idx} (Top {i+1}) not found in any of the molecules.")

# %%
draw_top_morgan_bits(df['Structure'], [917,23], nBits=1024  , radius=2, max_mols=200, molsPerRow=5)
# Out:
# Bit 917 (Top 1)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=750x6000>
# Bit 23 (Top 2)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=750x6000>

# %% [markdown]
# # Effect on similarity

# %%
### lets see if this works on a small number of molecules before we proceed

# %%
# sample random compounds and select te structures
df_sample = df.sample(n=1000, random_state=42)
mols = df_sample.Structure
n = len(mols)

# fingerprints
ecfp4 = [AllChem.GetMorganGenerator(radius = 2, fpSize=1024).GetFingerprint(m) for m in mols]
sparse_ecfp4 = [AllChem.GetMorganGenerator(radius=2).GetSparseFingerprint(m) for m in mols]

# initialize histogram
counts = np.zeros((100, 100))

# Loop over molecules, compare against all later ones
for i in range(n):
    sims_fold = DataStructs.BulkTanimotoSimilarity(ecfp4[i], ecfp4[i+1:])
    sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_ecfp4[i], sparse_ecfp4[i+1:])
    
    # update histogram 
    hist, _, _ = np.histogram2d(
        sims_fold, sims_sparse,
        bins=100, range=[[0,1],[0,1]]
    )
    counts += hist

# mask zero-count bins
counts_masked = np.ma.masked_where(counts == 0, counts)

# plot
plt.figure(figsize=(8, 6))

plt.pcolormesh(
    np.linspace(0,1,101),
    np.linspace(0,1,101),
    counts_masked.T,
    cmap="viridis",
    norm=LogNorm(vmin=1, vmax=counts.max())) # log scale is needed

plt.colorbar(label="count")
plt.xlabel("Tanimoto ECFP4 folded bit (1024)")
plt.ylabel("Tanimoto ECFP4 sparse bit")
plt.title(f"Similarity scores for unfolded vs folded\nfor {n} compounds")
plt.show()

# %% [markdown]
# ### looping over different lengths

# %%
# sample random compounds and select te structures
df_sample = df.sample(n=5000, random_state=42)
mols = df_sample.Structure
n = len(mols)

#sizes
sizes = [1024, 2048, 4096, 8192, 16384, 32768]

# fingerprints 
fingerprints = {size: [AllChem.GetMorganGenerator(radius = 2, fpSize=size).GetFingerprint(m) for m in mols] for size in sizes}
sparse_ecfp4 = [AllChem.GetMorganGenerator(radius=2).GetSparseFingerprint(m) for m in mols]

# subplot grid
fig, axes = plt.subplots(1, len(sizes), figsize=(6*len(sizes), 4), sharex=True, sharey=True)

for ax, size in zip(axes, sizes):
    ecfp = fingerprints[size]
    counts = np.zeros((100, 100))

    # histogram 
    for i in tqdm(range(n), desc=f"Processing fpSize={size}", unit="mol"):
        sims_fold = DataStructs.BulkTanimotoSimilarity(ecfp[i], ecfp[i+1:])
        sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_ecfp4[i], sparse_ecfp4[i+1:])
        
        hist, _, _ = np.histogram2d(
            sims_fold, sims_sparse,
            bins=100, range=[[0,1],[0,1]]
        )
        counts += hist

    # mask zero-count bin
    counts_masked = np.ma.masked_where(counts == 0, counts)

    #subplot
    mesh = ax.pcolormesh(
        np.linspace(0,1,101),
        np.linspace(0,1,101),
        counts_masked.T,
        cmap="viridis",
        norm=LogNorm(vmin=1, vmax=counts.max())
    )
    ax.set_xlabel(f"Tanimoto folded ECFP4-({size})")
    ax.set_ylabel("Tanimoto sparse ECFP4")
    ax.set_title(f"fpSize={size}")

#one shared colorbar
fig.colorbar(mesh, ax=axes, label="count", pad=0.02)
fig.suptitle(f"Similarity scores for unfolded vs folded ECFP4 for {n} compounds", fontsize=20, y=1.1, x=0.25)
plt.show()

# %% [raw]
# rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=nBits)
# rdFingerprintGenerator.GetAtomPairGenerator(fpSize=nBits)
# rdFingerprintGenerator.GetTopologicalTorsionGenerator(fpSize=nBits)

# %%
# Now for the rdFingerprintGenerator, that can be easily replaced by copy pasting the right 'Get...' in the code
# be aware the rdkit fps take very long to compute ~50 minutes

# define
df_sample = df.sample(n=5000, random_state=42)
mols = df_sample.Structure
n = len(mols)
sizes = [1024, 2048, 4096, 8192, 16384, 32768]
name='RDkit FP'

# fingerprints 
fingerprints = {size: [rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=size).GetFingerprint(m) for m in mols] for size in sizes}
sparse_fp = [rdFingerprintGenerator.GetRDKitFPGenerator().GetSparseFingerprint(m) for m in mols]

# subplot grid
fig, axes = plt.subplots(1, len(sizes), figsize=(6*len(sizes), 4), sharex=True, sharey=True)

for ax, size in zip(axes, sizes):
    fp = fingerprints[size]
    counts = np.zeros((100, 100))

    # make the 2d historgram
    for i in tqdm(range(n), desc=f"Processing fpSize={size}", unit="mol"):
        sims_fold = DataStructs.BulkTanimotoSimilarity(fp[i], fp[i+1:])
        sims_sparse = DataStructs.BulkTanimotoSimilarity(sparse_fp[i], sparse_fp[i+1:])
        
        hist, _, _ = np.histogram2d(
            sims_fold, sims_sparse,
            bins=100, range=[[0,1],[0,1]]
        )
        counts += hist

    # mask zero-count bin
    counts_masked = np.ma.masked_where(counts == 0, counts)

    # subplot
    mesh = ax.pcolormesh(
        np.linspace(0,1,101),
        np.linspace(0,1,101),
        counts_masked.T,
        cmap="viridis",
        norm=LogNorm(vmin=1, vmax=counts.max())
    )
    ax.set_xlabel(f"Tanimoto folded {name}")
    ax.set_ylabel(f"Tanimoto sparse {name}")
    ax.set_title(f"fpSize={size}")

#one shared colorbar
fig.colorbar(mesh, ax=axes, label="count", pad=0.02)
fig.suptitle(f"Similarity scores for unfolded vs folded {name} for {n} compounds", fontsize=20, y=1.1, x=0.25)
plt.show()
# Out:
# Processing fpSize=1024: 100%|█████████████████████████████████████████████████████| 5000/5000 [05:47<00:00, 14.40mol/s]
# Processing fpSize=2048: 100%|█████████████████████████████████████████████████████| 5000/5000 [08:28<00:00,  9.84mol/s]
# Processing fpSize=4096: 100%|█████████████████████████████████████████████████████| 5000/5000 [09:05<00:00,  9.16mol/s]
# Processing fpSize=8192: 100%|█████████████████████████████████████████████████████| 5000/5000 [09:06<00:00,  9.15mol/s]
# Processing fpSize=16384: 100%|████████████████████████████████████████████████████| 5000/5000 [09:20<00:00,  8.92mol/s]
# Processing fpSize=32768: 100%|████████████████████████████████████████████████████| 5000/5000 [05:54<00:00, 14.09mol/s]
